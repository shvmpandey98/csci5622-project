# %%
# Importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading the dataset
df = pd.read_parquet('data/final_data/final_dataset.parquet')

# Replacing NaN values with 0
df = df.fillna(0)

# %%
df.head()
# Out:
#         date  precip  max_temp  min_temp    gwl  daily_discharge_cfs  \
# 0 2010-02-14     0.0        36        13  20.52                136.0
# 1 2010-02-15     0.0        41         7  20.51                129.0
# 2 2010-02-16     0.0        43         8  20.51                130.0
# 3 2010-02-17     0.0        51        10  20.51                132.0
# 4 2010-02-18     0.0        51        16  20.50                135.0
#
#      sm_pca    st_pca  target
# 0  3.619512  0.190574       0
# 1  3.470118  0.209177       0
# 2  3.433721  0.197542       0
# 3  3.351107  0.135033       0
# 4  3.238121  0.107690       0

# %%
# Visualizing where target variable is 1 i.e there is drought

plt.figure(figsize=(10, 6))
plt.scatter(df[df['target'] == 1]['date'], df[df['target'] == 1]['target'])
plt.title('Drought occurance')
plt.xlabel('Date')
plt.ylabel('Drought Condition as 1')
plt.show()

# %%
# following are the features list

features = ['precip', 'max_temp', 'min_temp', 'gwl', 'daily_discharge_cfs','sm_pca', 'st_pca']
target = 'target'

# %%
# Checking for multicollinearity between features

corr = df[features].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_57d2c_row0_col0, #T_57d2c_row1_col1, #T_57d2c_row2_col2, #T_57d2c_row3_col3, #T_57d2c_row4_col4, #T_57d2c_row5_col5, #T_57d2c_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_57d2c_row0_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_57d2c_row0_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_57d2c_row0_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_57d2c_row0_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_57d2c_row0_col5, #T_57d2c_row4_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_57d2c_row0_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_57d2c_row1_col0, #T_57d2c_row2_col5, #T_57d2c_row3_col4, #T_57d2c_row3_col6, #T_57d2c_row5_col1, #T_57d2c_row5_col2, #T_57d2c_row6_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_57d2c_row1_col2, #T_57d2c_row2_col1 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_57d2c_row1_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_57d2c_row1_col4, #T_57d2c_row6_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_57d2c_row1_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_57d2c_row1_col6 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_57d2c_row2_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_57d2c_row2_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_57d2c_row2_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_57d2c_row2_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_57d2c_row3_col0, #T_57d2c_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_57d2c_row3_col1, #T_57d2c_row5_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_57d2c_row3_col2, #T_57d2c_row4_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_57d2c_row3_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_57d2c_row4_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_57d2c_row4_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_57d2c_row4_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_57d2c_row4_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_57d2c_row5_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_57d2c_row5_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_57d2c_row6_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_57d2c_row6_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_57d2c_row6_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_57d2c_row6_col5 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# </style>
# <table id="T_57d2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57d2c_level0_col0" class="col_heading level0 col0" >precip</th>
#       <th id="T_57d2c_level0_col1" class="col_heading level0 col1" >max_temp</th>
#       <th id="T_57d2c_level0_col2" class="col_heading level0 col2" >min_temp</th>
#       <th id="T_57d2c_level0_col3" class="col_heading level0 col3" >gwl</th>
#       <th id="T_57d2c_level0_col4" class="col_heading level0 col4" >daily_discharge_cfs</th>
#       <th id="T_57d2c_level0_col5" class="col_heading level0 col5" >sm_pca</th>
#       <th id="T_57d2c_level0_col6" class="col_heading level0 col6" >st_pca</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57d2c_level0_row0" class="row_heading level0 row0" >precip</th>
#       <td id="T_57d2c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_57d2c_row0_col1" class="data row0 col1" >-0.032593</td>
#       <td id="T_57d2c_row0_col2" class="data row0 col2" >0.104749</td>
#       <td id="T_57d2c_row0_col3" class="data row0 col3" >-0.024576</td>
#       <td id="T_57d2c_row0_col4" class="data row0 col4" >0.206089</td>
#       <td id="T_57d2c_row0_col5" class="data row0 col5" >-0.024596</td>
#       <td id="T_57d2c_row0_col6" class="data row0 col6" >-0.001298</td>
#     </tr>
#     <tr>
#       <th id="T_57d2c_level0_row1" class="row_heading level0 row1" >max_temp</th>
#       <td id="T_57d2c_row1_col0" class="data row1 col0" >-0.032593</td>
#       <td id="T_57d2c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_57d2c_row1_col2" class="data row1 col2" >0.861268</td>
#       <td id="T_57d2c_row1_col3" class="data row1 col3" >0.063881</td>
#       <td id="T_57d2c_row1_col4" class="data row1 col4" >0.010227</td>
#       <td id="T_57d2c_row1_col5" class="data row1 col5" >-0.390845</td>
#       <td id="T_57d2c_row1_col6" class="data row1 col6" >-0.302978</td>
#     </tr>
#     <tr>
#       <th id="T_57d2c_level0_row2" class="row_heading level0 row2" >min_temp</th>
#       <td id="T_57d2c_row2_col0" class="data row2 col0" >0.104749</td>
#       <td id="T_57d2c_row2_col1" class="data row2 col1" >0.861268</td>
#       <td id="T_57d2c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_57d2c_row2_col3" class="data row2 col3" >0.046226</td>
#       <td id="T_57d2c_row2_col4" class="data row2 col4" >0.101598</td>
#       <td id="T_57d2c_row2_col5" class="data row2 col5" >-0.406750</td>
#       <td id="T_57d2c_row2_col6" class="data row2 col6" >-0.333921</td>
#     </tr>
#     <tr>
#       <th id="T_57d2c_level0_row3" class="row_heading level0 row3" >gwl</th>
#       <td id="T_57d2c_row3_col0" class="data row3 col0" >-0.024576</td>
#       <td id="T_57d2c_row3_col1" class="data row3 col1" >0.063881</td>
#       <td id="T_57d2c_row3_col2" class="data row3 col2" >0.046226</td>
#       <td id="T_57d2c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_57d2c_row3_col4" class="data row3 col4" >-0.056801</td>
#       <td id="T_57d2c_row3_col5" class="data row3 col5" >0.019720</td>
#       <td id="T_57d2c_row3_col6" class="data row3 col6" >-0.452011</td>
#     </tr>
#     <tr>
#       <th id="T_57d2c_level0_row4" class="row_heading level0 row4" >daily_discharge_cfs</th>
#       <td id="T_57d2c_row4_col0" class="data row4 col0" >0.206089</td>
#       <td id="T_57d2c_row4_col1" class="data row4 col1" >0.010227</td>
#       <td id="T_57d2c_row4_col2" class="data row4 col2" >0.101598</td>
#       <td id="T_57d2c_row4_col3" class="data row4 col3" >-0.056801</td>
#       <td id="T_57d2c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_57d2c_row4_col5" class="data row4 col5" >0.024787</td>
#       <td id="T_57d2c_row4_col6" class="data row4 col6" >0.018521</td>
#     </tr>
#     <tr>
#       <th id="T_57d2c_level0_row5" class="row_heading level0 row5" >sm_pca</th>
#       <td id="T_57d2c_row5_col0" class="data row5 col0" >-0.024596</td>
#       <td id="T_57d2c_row5_col1" class="data row5 col1" >-0.390845</td>
#       <td id="T_57d2c_row5_col2" class="data row5 col2" >-0.406750</td>
#       <td id="T_57d2c_row5_col3" class="data row5 col3" >0.019720</td>
#       <td id="T_57d2c_row5_col4" class="data row5 col4" >0.024787</td>
#       <td id="T_57d2c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_57d2c_row5_col6" class="data row5 col6" >0.312463</td>
#     </tr>
#     <tr>
#       <th id="T_57d2c_level0_row6" class="row_heading level0 row6" >st_pca</th>
#       <td id="T_57d2c_row6_col0" class="data row6 col0" >-0.001298</td>
#       <td id="T_57d2c_row6_col1" class="data row6 col1" >-0.302978</td>
#       <td id="T_57d2c_row6_col2" class="data row6 col2" >-0.333921</td>
#       <td id="T_57d2c_row6_col3" class="data row6 col3" >-0.452011</td>
#       <td id="T_57d2c_row6_col4" class="data row6 col4" >0.018521</td>
#       <td id="T_57d2c_row6_col5" class="data row6 col5" >0.312463</td>
#       <td id="T_57d2c_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that there is correlation between max_temp and min_temp, but as per the domain knowledge, we know that these two features are important and we should keep them

# %%
# Displaying the data before splitting

display(df[features].head())

display(df[[target]].head())
# Out:
#    precip  max_temp  min_temp    gwl  daily_discharge_cfs    sm_pca    st_pca
# 0     0.0        36        13  20.52                136.0  3.619512  0.190574
# 1     0.0        41         7  20.51                129.0  3.470118  0.209177
# 2     0.0        43         8  20.51                130.0  3.433721  0.197542
# 3     0.0        51        10  20.51                132.0  3.351107  0.135033
# 4     0.0        51        16  20.50                135.0  3.238121  0.107690
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Splitting the dataset into the Training set and Test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size = 0.2, random_state = 0)

# %%
# No. of instance with 1 in target variable for training set
display(y_train.value_counts())

# No. of instance with 1 in target variable for test set
display(y_test.value_counts())
# Out:
# target
# 0    2218
# 1    1686
# Name: count, dtype: int64
# target
# 0    536
# 1    441
# Name: count, dtype: int64

# %%
# display the data after splitting

# Training set
display(pd.DataFrame(X_train).head())
display(pd.DataFrame(y_train).head())

# Test set
display(pd.DataFrame(X_test).head())
display(pd.DataFrame(y_test).head())
# Out:
#       precip  max_temp  min_temp    gwl  daily_discharge_cfs    sm_pca  \
# 641     0.00        57        11  21.00                145.0  0.494067
# 333     0.11        35        19  20.84                 93.7 -0.995163
# 33      0.08        40        25  20.44                120.0 -0.179378
# 3909    0.00        41         8  21.71                 96.9 -0.002604
# 4193    0.00        62        32  22.13                150.0  0.943268
#
#         st_pca
# 641  -1.976446
# 333   0.067906
# 33    1.826560
# 3909  1.751204
# 4193 -1.191578
#       target
# 641        1
# 333        0
# 33         0
# 3909       1
# 4193       1
#       precip  max_temp  min_temp    gwl  daily_discharge_cfs    sm_pca  \
# 2857    0.01        47        22  21.16                170.0  2.224886
# 2373    0.00        75        30  21.73                100.0  0.893778
# 1065    0.00        48        17  21.00                 78.3  0.303675
# 2287    0.00        97        60  21.31                112.0 -0.647494
# 1675    0.00        80        42  21.45                163.0 -0.127969
#
#         st_pca
# 2857  2.490720
# 2373 -1.718663
# 1065  0.066434
# 2287 -0.541322
# 1675 -1.816134
#       target
# 2857       0
# 2373       0
# 1065       1
# 2287       0
# 1675       0

# %%
# Scaling the features
# Feature scaling is performed to ensure that the model is not biased towards the features with higher magnitude

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

# %%
# Displaying the scaled training set

display(pd.DataFrame(X_train).head())
# Out:
#           0         1         2         3         4         5         6
# 0 -0.236413 -0.703677 -1.472493 -0.789317 -0.043247  0.398965 -1.188105
# 1  0.574686 -1.801402 -1.034528 -1.157828 -0.211894 -0.693305  0.026048
# 2  0.353477 -1.551919 -0.706055 -2.079106 -0.125433 -0.094971  1.070523
# 3 -0.236413 -1.502023 -1.636730  0.845953 -0.201374  0.034684  1.025768
# 4 -0.236413 -0.454194 -0.322836  1.813295 -0.026809  0.728431 -0.721967

# %%
# Impenting Naive Bayes Classifier

from sklearn.naive_bayes import GaussianNB

classifier = GaussianNB()
classifier.fit(X_train, y_train)

preds = classifier.predict(sc.transform(X_test)) # Predicting the Test set results

# %%
# Generating the confusion matrix

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score, recall_score

cm = confusion_matrix(y_test, preds)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)

disp.plot()

# %%
# Accuracy, F1 Score and Recall Score

accuracy = accuracy_score(y_test, preds)
f1 = f1_score(y_test, preds)
recall = recall_score(y_test, preds)

print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
print(f'Recall Score: {recall}')
# Out:
# Accuracy: 0.5547594677584442
# F1 Score: 0.5845272206303725
# Recall Score: 0.6938775510204082
