# %% [markdown]
# ## Colorado Stream Flow Data

# %%
# Importing the necessary libraries
import dataretrieval.nwis as nwis
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Fetching the data from the USGS NWIS via API call using the dataretrieval library

# %%
# UNCOMPAHGRE RIVER NEAR OURAY, CO
# USGS URL: https://dashboard.waterdata.usgs.gov/api/gwis/2.1/service/site?agencyCode=USGS&siteNumber=09146200&open=211902

site = '09146020'  # Uncompahgre River near Ouray, CO

display(nwis.get_record(sites=site, service='site')) # Site information

# get instantaneous values (iv)
df_uncompahgre_river = nwis.get_record(sites=site, service='dv', start='2009-01-01', end='2024-02-08').reset_index()

display(df_uncompahgre_river.head()) # Raw data

df_uncompahgre_river = df_uncompahgre_river[['datetime', '00060_Mean']]
df_uncompahgre_river.columns = ['datetime', 'daily_discharge_cfs']

df_uncompahgre_river['datetime'] = df_uncompahgre_river['datetime'].dt.date # Extracting date from datetime

display(df_uncompahgre_river.head())
# Out:
#   agency_cd   site_no                        station_nm site_tp_cd  lat_va  \
# 0      USGS  09146020  UNCOMPAHGRE RIVER NEAR OURAY, CO         ST  380236
#
#    long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0  1074057   38.043327  -107.683115             M            S  ...
#
#   local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd aqfr_type_cd  \
# 0             Y            NaN    NYNNNNNN          NaN      NaN          NaN
#
#   well_depth_va hole_depth_va  depth_src_cd  project_no
# 0           NaN           NaN           NaN   460800110
#
# [1 rows x 42 columns]
#                    datetime  00060_Mean 00060_Mean_cd   site_no
# 0 2009-01-01 00:00:00+00:00        33.1             A  09146020
# 1 2009-01-02 00:00:00+00:00        32.2             A  09146020
# 2 2009-01-03 00:00:00+00:00        31.2             A  09146020
# 3 2009-01-04 00:00:00+00:00        28.0             A  09146020
# ...

# %%
# UNCOMPAHGRE RIVER NEAR RIDGWAY, CO
# USGS URL: https://dashboard.waterdata.usgs.gov/api/gwis/2.1/service/site?agencyCode=USGS&siteNumber=09146200&open=211902

site = '09146200' # Uncompahgre River near Ridgway, CO
display(nwis.get_record(sites=site, service='site')) # Site information

# get instantaneous values (iv)
df_uncompahgre_river_ridgway = nwis.get_record(sites=site, service='dv', start='2009-01-01', end='2024-02-08').reset_index()

display(df_uncompahgre_river_ridgway.head()) # Raw data

df_uncompahgre_river_ridgway = df_uncompahgre_river_ridgway[['datetime', '00060_Mean']]
df_uncompahgre_river_ridgway.columns = ['datetime', 'daily_discharge_cfs']

df_uncompahgre_river_ridgway['datetime'] = df_uncompahgre_river_ridgway['datetime'].dt.date # Extracting date from datetime

display(df_uncompahgre_river_ridgway.head())
# Out:
#   agency_cd   site_no                           station_nm site_tp_cd  lat_va  \
# 0      USGS  09146200  UNCOMPAHGRE RIVER NEAR RIDGWAY, CO.         ST  381102
#
#    long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0  1074443   38.183879  -107.745892             M            S  ...
#
#   local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd aqfr_type_cd  \
# 0             Y            NaN    NYNNNNNN          NaN      NaN          NaN
#
#   well_depth_va  hole_depth_va  depth_src_cd  project_no
# 0           NaN            NaN           NaN         NaN
#
# [1 rows x 42 columns]
#                    datetime  00060_Mean 00060_Mean_cd   site_no
# 0 2009-01-01 00:00:00+00:00        55.3             A  09146200
# 1 2009-01-02 00:00:00+00:00        55.0             A  09146200
# 2 2009-01-03 00:00:00+00:00        55.2             A  09146200
# 3 2009-01-04 00:00:00+00:00        53.3             A  09146200
# ...

# %%
# ARKANSAS RIVER TRIBUTARY ABOVE HWY 227 AT PUEBLO
# USGS URL: https://dashboard.waterdata.usgs.gov/api/gwis/2.1/service/site?agencyCode=USGS&siteNumber=07099973&open=211166

site = '07099973' # Arkansas River tributary above Hwy 227 at Pueblo, CO
display(nwis.get_record(sites=site, service='site')) # Site information

# get instantaneous values (iv)
df_arkansas_pueblo = nwis.get_record(sites=site, service='dv', start='2009-01-01', end='2024-02-08').reset_index()

display(df_arkansas_pueblo.head()) # Raw data

df_arkansas_pueblo = df_arkansas_pueblo[['datetime', '00060_Mean']]
df_arkansas_pueblo.columns = ['datetime', 'daily_discharge_cfs']

df_arkansas_pueblo['datetime'] = df_arkansas_pueblo['datetime'].dt.date # Extracting date from datetime

display(df_arkansas_pueblo.head())
# Out:
#   agency_cd   site_no                                        station_nm  \
# 0      USGS  07099973  ARKANSAS RIVER TRIBUTARY ABOVE HWY 227 AT PUEBLO
#
#   site_tp_cd  lat_va  long_va  dec_lat_va  dec_long_va coord_meth_cd  \
# 0         ST  381514  1043545   38.253889  -104.595833             G
#
#   coord_acy_cd  ... local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  \
# 0            S  ...             Y            NaN         NaN          NaN
#
#    aqfr_cd aqfr_type_cd well_depth_va hole_depth_va  depth_src_cd  project_no
# 0      NaN          NaN           NaN           NaN           NaN   858200141
#
# [1 rows x 42 columns]
#                    datetime  00060_Mean 00060_Mean_cd   site_no
# 0 2009-01-01 00:00:00+00:00        36.4             A  07099973
# 1 2009-01-02 00:00:00+00:00        36.6             A  07099973
# 2 2009-01-03 00:00:00+00:00        36.5             A  07099973
# 3 2009-01-04 00:00:00+00:00        36.5             A  07099973
# ...

# %%
# ARKANSAS RIVER BELOW JOHN MARTIN RESERVOIR, CO
# USGS URL: https://dashboard.waterdata.usgs.gov/api/gwis/2.1/service/site?agencyCode=USGS&siteNumber=07130500&open=211406

site = '07130500' # Arkansas River below John Martin Reservoir, CO
display(nwis.get_record(sites=site, service='site')) # Site information

# get instantaneous values (iv)
df_arkansas_john_martin = nwis.get_record(sites=site, service='dv', start='2009-01-01', end='2024-02-08').reset_index()

display(df_arkansas_john_martin.head()) # Raw data

df_arkansas_john_martin = df_arkansas_john_martin[['datetime', '00060_Mean']]
df_arkansas_john_martin.columns = ['datetime', 'daily_discharge_cfs']

df_arkansas_john_martin['datetime'] = df_arkansas_john_martin['datetime'].dt.date # Extracting date from datetime

display(df_arkansas_john_martin.head())
# Out:
#   agency_cd   site_no                                       station_nm  \
# 0      USGS  07130500  ARKANSAS RIVER BELOW JOHN MARTIN RESERVOIR, CO.
#
#   site_tp_cd  lat_va  long_va  dec_lat_va  dec_long_va coord_meth_cd  \
# 0         ST  380359  1025555   38.066396  -102.932423             M
#
#   coord_acy_cd  ... local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  \
# 0            F  ...             Y            NaN    NYNNNNNN          NaN
#
#    aqfr_cd aqfr_type_cd well_depth_va  hole_depth_va  depth_src_cd  project_no
# 0      NaN          NaN           NaN            NaN           NaN         NaN
#
# [1 rows x 42 columns]
#                    datetime  00010_Maximum 00010_Maximum_cd   site_no  \
# 0 2009-01-01 00:00:00+00:00            4.1                A  07130500
# 1 2009-01-02 00:00:00+00:00            4.7                A  07130500
# 2 2009-01-03 00:00:00+00:00            4.4                A  07130500
# ...

# %%
# FOUNTAIN CREEK AT PUEBLO, CO
# USGS URL: https://dashboard.waterdata.usgs.gov/api/gwis/2.1/service/site?agencyCode=USGS&siteNumber=07106500&open=211313

site = '07106500' # Fountain Creek at Pueblo, CO
display(nwis.get_record(sites=site, service='site')) # Site information

# get instantaneous values (iv)
df_fountain_creek = nwis.get_record(sites=site, service='dv', start='2009-01-01', end='2024-02-08').reset_index()

display(df_fountain_creek.head()) # Raw data

df_fountain_creek = df_fountain_creek[['datetime', '00060_Mean']]
df_fountain_creek.columns = ['datetime', 'daily_discharge_cfs']

df_fountain_creek['datetime'] = df_fountain_creek['datetime'].dt.date # Extracting date from datetime

display(df_fountain_creek.head())
# Out:
#   agency_cd   site_no                     station_nm site_tp_cd  lat_va  \
# 0      USGS  07106500  FOUNTAIN CREEK AT PUEBLO, CO.         ST  381716
#
#    long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0  1043602    38.28778  -104.601085             M            F  ...
#
#   local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd aqfr_type_cd  \
# 0             Y            NaN    NYNNNNNN          NaN      NaN          NaN
#
#   well_depth_va  hole_depth_va  depth_src_cd  project_no
# 0           NaN            NaN           NaN         NaN
#
# [1 rows x 42 columns]
#                    datetime  00010_Maximum 00010_Maximum_cd   site_no  \
# 0 2009-01-01 00:00:00+00:00            8.0                A  07106500
# 1 2009-01-02 00:00:00+00:00            8.2                A  07106500
# 2 2009-01-03 00:00:00+00:00            5.7                A  07106500
# 3 2009-01-04 00:00:00+00:00            2.6                A  07106500
# ...

# %% [markdown]
# #### Uncompahgre River near Ouray, CO Streamflow Data Analysis

# %%
# Summary of the data for Uncompahgre River near Ouray, CO
display(df_uncompahgre_river.describe())

# Here -999999 is the missing value. We will remove those rows.
df_uncompahgre_river = df_uncompahgre_river[df_uncompahgre_river['daily_discharge_cfs'] != -999999]

# Summary of the data for Uncompahgre River near Ouray, CO after removing missing values
display(df_uncompahgre_river.describe())
# Out:
#        daily_discharge_cfs
# count          5517.000000
# mean            120.861102
# std             171.122062
# min              10.300000
# 25%              28.900000
# 50%              47.900000
# 75%             124.000000
# max            1200.000000
#        daily_discharge_cfs
# count          5517.000000
# mean            120.861102
# std             171.122062
# min              10.300000
# 25%              28.900000
# 50%              47.900000
# 75%             124.000000
# max            1200.000000

# %%
# Plotting time series of daily discharge for Uncompahgre River near Ouray, CO

plt.figure(figsize=(15, 6))
plt.plot(df_uncompahgre_river['datetime'], df_uncompahgre_river['daily_discharge_cfs'], label='Uncompahgre River near Ouray, CO')
plt.xlabel('Date')
plt.ylabel('Daily Discharge (cfs)')
plt.title('Daily Discharge of Uncompahgre River near Ouray, CO')
plt.legend()
plt.show()

# %%
# Plotting distribution of daily discharge for Uncompahgre River near Ouray, CO

plt.figure(figsize=(15, 6))
plt.hist(df_uncompahgre_river['daily_discharge_cfs'], bins=50, alpha=0.7, color='blue')
plt.xlabel('Daily Discharge (cfs)')
plt.ylabel('Frequency')
plt.title('Distribution of Daily Discharge of Uncompahgre River near Ouray, CO')
plt.show()

# %% [markdown]
# #### Uncompahgre River near Ridgway, CO Streamflow Data Analysis

# %%
# Summary of the data for Uncompahgre River near Ridgway, CO
display(df_uncompahgre_river_ridgway.describe())

# Here -999999 is the missing value. We will remove those rows.
df_uncompahgre_river_ridgway = df_uncompahgre_river_ridgway[df_uncompahgre_river_ridgway['daily_discharge_cfs'] != -999999]

# Summary of the data for Uncompahgre River near Ridgway, CO after removing missing values
display(df_uncompahgre_river_ridgway.describe())
# Out:
#        daily_discharge_cfs
# count          5502.000000
# mean          -2032.337259
# std           46661.994749
# min         -999999.000000
# 25%              49.300000
# 50%              72.100000
# 75%             157.000000
# max            1390.000000
#        daily_discharge_cfs
# count          5490.000000
# mean            149.010638
# std             183.347319
# min              27.800000
# 25%              49.400000
# 50%              72.250000
# 75%             157.000000
# max            1390.000000

# %%
# Plotting time series of daily discharge for Uncompahgre River near Ridgway, CO (do not scale values for y axis, show as it is)

plt.figure(figsize=(15, 6))
plt.plot(df_uncompahgre_river_ridgway['datetime'], df_uncompahgre_river_ridgway['daily_discharge_cfs'], label='Uncompahgre River near Ridgway, CO')
plt.xlabel('Date')
plt.ylabel('Daily Discharge (cfs)')
plt.title('Daily Discharge of Uncompahgre River near Ridgway, CO')
plt.legend()
plt.show()

# %%
# Plotting distribution of daily discharge for Uncompahgre River near Ridgway, CO

plt.figure(figsize=(15, 6))
plt.hist(df_uncompahgre_river_ridgway['daily_discharge_cfs'], bins=50, alpha=0.7, color='blue')
plt.xlabel('Daily Discharge (cfs)')
plt.ylabel('Frequency')
plt.title('Distribution of Daily Discharge of Uncompahgre River near Ridgway, CO')
plt.show()

# %% [markdown]
# #### Arkansas River tributary above Hwy 227 at Pueblo, CO Streamflow Data Analysis

# %%
# Summary of the data for Arkansas River tributary above Hwy 227 at Pueblo, CO
display(df_arkansas_pueblo.describe())
# Out:
#        daily_discharge_cfs
# count          5517.000000
# mean             32.544330
# std              17.835622
# min               0.280000
# 25%              19.300000
# 50%              30.400000
# 75%              44.800000
# max             113.000000

# %%
# Plotting time series of daily discharge for Arkansas River tributary above Hwy 227 at Pueblo, CO

plt.figure(figsize=(15, 6))
plt.plot(df_arkansas_pueblo['datetime'], df_arkansas_pueblo['daily_discharge_cfs'], label='Arkansas River tributary above Hwy 227 at Pueblo, CO')
plt.xlabel('Date')
plt.ylabel('Daily Discharge (cfs)')
plt.title('Daily Discharge of Arkansas River tributary above Hwy 227 at Pueblo, CO')
plt.legend()
plt.show()

# %%
# Plotting distribution of daily discharge for Arkansas River tributary above Hwy 227 at Pueblo, CO

plt.figure(figsize=(15, 6))
plt.hist(df_arkansas_pueblo['daily_discharge_cfs'], bins=50, alpha=0.7, color='blue')
plt.xlabel('Daily Discharge (cfs)')
plt.ylabel('Frequency')
plt.title('Distribution of Daily Discharge of Arkansas River tributary above Hwy 227 at Pueblo, CO')
plt.show()

# %% [markdown]
# #### Arkansas River below John Martin Reservoir, CO Streamflow Data Analysis

# %%
# Summary of the data for Arkansas River below John Martin Reservoir, CO
display(df_arkansas_john_martin.describe())
# Out:
#        daily_discharge_cfs
# count          5517.000000
# mean            246.495842
# std             351.147877
# min               0.000000
# 25%               1.040000
# 50%              47.200000
# 75%             451.000000
# max            1720.000000

# %%
# Plotting time series of daily discharge for Arkansas River below John Martin Reservoir, CO

plt.figure(figsize=(15, 6))
plt.plot(df_arkansas_john_martin['datetime'], df_arkansas_john_martin['daily_discharge_cfs'], label='Arkansas River below John Martin Reservoir, CO')
plt.xlabel('Date')
plt.ylabel('Daily Discharge (cfs)')
plt.title('Daily Discharge of Arkansas River below John Martin Reservoir, CO')
plt.legend()
plt.show()

# %%
# Plotting distribution of daily discharge for Arkansas River below John Martin Reservoir, CO

plt.figure(figsize=(15, 6))
plt.hist(df_arkansas_john_martin['daily_discharge_cfs'], bins=50, alpha=0.7, color='blue')
plt.xlabel('Daily Discharge (cfs)')
plt.ylabel('Frequency')
plt.title('Distribution of Daily Discharge of Arkansas River below John Martin Reservoir, CO')
plt.show()

# %% [markdown]
# #### Fountain Creek at Pueblo, CO Streamflow Data Analysis

# %%
# Summary of the data for Fountain Creek at Pueblo, CO
display(df_fountain_creek.describe())
# Out:
#        daily_discharge_cfs
# count          5517.000000
# mean            152.783902
# std             275.654867
# min               4.000000
# 25%              75.000000
# 50%             109.000000
# 75%             153.000000
# max            6550.000000

# %%
# Plotting time series of daily discharge for Fountain Creek at Pueblo, CO

plt.figure(figsize=(15, 6))
plt.plot(df_fountain_creek['datetime'], df_fountain_creek['daily_discharge_cfs'], label='Fountain Creek at Pueblo, CO')
plt.xlabel('Date')
plt.ylabel('Daily Discharge (cfs)')
plt.title('Daily Discharge of Fountain Creek at Pueblo, CO')
plt.legend()
plt.show()

# %%
# Plotting distribution of daily discharge for Fountain Creek at Pueblo, CO

plt.figure(figsize=(15, 6))
plt.hist(df_fountain_creek['daily_discharge_cfs'], bins=50, alpha=0.7, color='blue')
plt.xlabel('Daily Discharge (cfs)')
plt.ylabel('Frequency')
plt.title('Distribution of Daily Discharge of Fountain Creek at Pueblo, CO')
plt.show()

# %%
# Saving the data to parquet files for reuse

df_uncompahgre_river.to_parquet('data/streamflow_data/uncompahgre_river_ouray.parquet')
df_uncompahgre_river_ridgway.to_parquet('data/streamflow_data/uncompahgre_river_ridgway.parquet')
df_fountain_creek.to_parquet('data/streamflow_data/fountain_creek.parquet')
df_arkansas_pueblo.to_parquet('data/streamflow_data/arkansas_pueblo.parquet')
df_arkansas_john_martin.to_parquet('data/streamflow_data/arkansas_john_martin.parquet')
